# %%
from math import *
import time
def calc():
    print("Select operation: ")
    time.sleep(1)
    print("1. Addition")
    time.sleep(1)
    print("2. Subtraction")
    time.sleep(1)
    print("3. Multiplication")
    time.sleep(1)
    print("4. Division")
    time.sleep(1)
    print("5. Exponents")
    time.sleep(1)
    print("6. Sin function")
    time.sleep(1)
    print("7. Cos function")
    time.sleep(1)
    print("8. Tan function")
    time.sleep(1)
    print("9. Sec function")
    time.sleep(1)
    print("10. Cosec function")
    time.sleep(1)
    print("11. Cot function")
    time.sleep(1)
    print("12. Logarithmic")
    time.sleep(1)
    print("13. Factorial ")
    time.sleep(1)
    operation=int(input("Enter the operation (1-13)"))
    match operation:
        case 1:
            a=float(input("Enter first val: "))
            b=float(input("Enter second val: "))
            print(a,"+",b," = ",a+b)
             
        case 2:
            a=float(input("Enter first val: "))
            b=float(input("Enter second val: "))
            print(a,"-",b," = ",a-b)
        case 3:
            a=float(input("Enter first val: "))
            b=float(input("Enter second val: "))
            print(a,"*",b," = ",a*b)
        case 4:
            a=float(input("Enter first val: "))
            b=float(input("Enter second val: "))
            if b != 0:
                print(a,"/",b," = ",a/b)
            else:
                print("Division by zero is not possible ")
        case 5:
            a=float(input("Enter first val: "))
            b=float(input("Enter second val: "))
            print(a,"to the power of ",b," is ",a**b)
        case 6:
            a=float(input("Enter the radian value as x: "))
            print(f"sin({a}) = {sin(a)}")
        case 7:
            a=float(input("Enter the radian value as x: "))
            print(f"cos({a}) = {cos(a)}")
        case 8:
            a=float(input("Enter the radian value as x: "))
            print(f"tan({a}) = {tan(a)}")
        case 9:
            a=float(input("Enter the radian value as x: "))
            print(f"sec({a}) = {1/cos(a)}")
        case 10:
            a=float(input("Enter the radian value as x: "))
            print(f"cosec({a}) = {1/sin(a)}")
        case 11:
            a=float(input("Enter the radian value as x: "))
            print(f"cot({a}) = {1/tan(a)}")
        case 12:
            a=float(input("Enter the val: "))
            if a>0:
                print(f"log({a}) = {log10(a)}")#log with base 10
                print(f"ln({a}) = {log(a)}")#natural log or ln
            else:
                print("Log values can only be found for positive")
        case 13:
            ans=input("factorial of integer or decimal: ")
            if ans.lower()=="integer":
                a=int(input("Enter an integer val: "))
                if a>0:
                    print(f"{a}! = {factorial(a)}")
                else:
                    print("Factorial can be found only for non negative numbers")
            if ans.lower()=="decimal":
                a=float(input("Enter a decimal val: "))
                if a>0:
                    print(f"{a}! = {gamma(a+1)}")
                else:
                    print("Factorial can be found only for non negative numbers")
        case _:
            print("Invalid Input")
            print("Run again with valid input")
calc()
# Out:
# Select operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exponents
# 6. Sin function
# 7. Cos function
# 8. Tan function
# 9. Sec function
# 10. Cosec function
# 11. Cot function
# 12. Logarithmic
# 13. Factorial
# Factorial can be found only for non negative numbers
